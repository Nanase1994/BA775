# %% [markdown]
# <a href="https://colab.research.google.com/github/Nanase1994/BA775/blob/main/Assignment_1_KEY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment 1 - BA775
#
# Note that this assignment captures topics from classes 3 & 4. You should run your queries in BigQuery or a Vertex AI notebook and submit the answers with your code in the rationale box of Blackboard (under the Assessment tab). 50% of the grade comes from the rationale and the other 50% from the multiple-choice answers.

# %% [markdown]
# ### Question 1&2
#
# Using the following table (`bigquery-public-data.baseball.schedules`), which baseball game had the biggest attendance in 2016?

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# %%bigquery  --project=ba-770
# SELECT * FROM `bigquery-public-data.baseball.schedules` LIMIT 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                  gameId  gameNumber  \
# 0  e14b6493-9e7f-404f-840a-8a680cc364bf           1
# 1  1f32b347-cbcb-4c31-a145-0e685306d168           1
# 2  0c2292d1-7398-48be-bf8e-b41dad5e1a43           1
# 3  8fbec734-a15a-42ab-8d51-60790de7750b           1
# 4  89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd           1
#
#                                seasonId  year type dayNight duration  \
# 0  565de4be-dc80-4849-a7e1-54bc79156cc8  2016  REG        D     3:07
# 1  565de4be-dc80-4849-a7e1-54bc79156cc8  2016  REG        D     3:09
# 2  565de4be-dc80-4849-a7e1-54bc79156cc8  2016  REG        D     2:45
# 3  565de4be-dc80-4849-a7e1-54bc79156cc8  2016  REG        D     3:42
# 4  565de4be-dc80-4849-a7e1-54bc79156cc8  2016  REG        D     2:44
#
#    duration_minutes                            homeTeamId homeTeamName  \
# 0               187  03556285-bdbb-4576-a06d-42f71f46ddc5      Marlins
# 1               189  03556285-bdbb-4576-a06d-42f71f46ddc5      Marlins
# 2               165  12079497-e414-450a-8bf2-29f91de646bf       Braves
# 3               222  12079497-e414-450a-8bf2-29f91de646bf       Braves
# 4               164  2142e1ba-3b40-445c-b8bb-f1f8b1054220     Phillies
#
#                              awayTeamId awayTeamName  \
# 0  55714da8-fcaf-4574-8443-59bfb511a524         Cubs
# 1  55714da8-fcaf-4574-8443-59bfb511a524         Cubs
# 2  55714da8-fcaf-4574-8443-59bfb511a524         Cubs
# 3  55714da8-fcaf-4574-8443-59bfb511a524         Cubs
# 4  55714da8-fcaf-4574-8443-59bfb511a524         Cubs
#
#                   startTime  attendance  status                   created
# 0 2016-06-26 17:10:00+00:00       27318  closed 2016-10-06 06:25:15+00:00
# 1 2016-06-25 20:10:00+00:00       29457  closed 2016-10-06 06:25:15+00:00
# 2 2016-06-11 20:10:00+00:00       43114  closed 2016-10-06 06:25:15+00:00
# 3 2016-06-12 17:35:00+00:00       31625  closed 2016-10-06 06:25:15+00:00
# 4 2016-06-08 17:05:00+00:00       28650  closed 2016-10-06 06:25:15+00:00

# %%
# %%bigquery  --project=ba-770
# # Your answer goes here
# SELECT homeTeamName, awayTeamName, attendance FROM `bigquery-public-data.baseball.schedules`
# WHERE year = 2016
# ORDER BY attendance DESC
# LIMIT 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   homeTeamName awayTeamName  attendance
# 0      Dodgers       Giants       53621
# 1      Dodgers       Giants       53449
# 2      Dodgers       Giants       53409
# 3      Dodgers      Rockies       53299
# 4      Dodgers       Giants       53297

# %% [markdown]
# ### Question 3&4
#
# In 2016, which team played the longest games at home on average?
#
# Hint: You will need to take the average `duration_minutes` for each `homeTeamName`. This can be achieved by a `GROUP BY` and then an `ORDER BY`.

# %%
# %%bigquery  --project=ba-770
# # Your answer goes here
# SELECT homeTeamName, AVG(duration_minutes) FROM `bigquery-public-data.baseball.schedules`
# WHERE year = 2016
# GROUP BY homeTeamName
# ORDER BY 2 DESC
# LIMIT 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    homeTeamName         f0_
# 0  Diamondbacks  197.111111
# 1       Red Sox  196.012346
# 2       Rockies  193.629630
# 3        Braves  192.185185
# 4          Mets  188.543210

# %% [markdown]
# ---
# ---
# The remaining questions refer to table `bigquery-public-data.austin_bikeshare.bikeshare_trips`.

# %%
# %%bigquery  --project=ba-770
# SELECT * FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips` LIMIT 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     trip_id                        subscriber_type bike_id bike_type  \
# 0  19061564          $1 Pay by Trip Winter Special   198BB  electric
# 1  19061145                   24 Hour Walk Up Pass    133G   classic
# 2  19061503          $1 Pay by Trip Winter Special     589   classic
# 3  18992755  Local365- 1/2 off Anniversary Special     302   classic
# 4  19084852                                Local30     391   classic
#
#                  start_time  start_station_id  start_station_name  \
# 0 2018-12-04 13:01:17+00:00              4051    10th & Red River
# 1 2018-12-04 11:29:04+00:00              4051    10th & Red River
# 2 2018-12-04 12:47:27+00:00              4051    10th & Red River
# 3 2018-11-16 20:24:30+00:00              3291  11th & San Jacinto
# 4 2018-12-11 17:44:39+00:00              3291  11th & San Jacinto
#
#   end_station_id  end_station_name  duration_minutes
# 0           4051  10th & Red River               190
# 1           4051  10th & Red River                44
# 2           4051  10th & Red River                 7
# 3           4051  10th & Red River                 2
# 4           4051  10th & Red River                 3

# %% [markdown]
# ### Question 5&6
#
# How many distinct and valid station IDs are in this table? Valid station IDs are integer numbers.
#
# **Note1:** notice that we are looking for valid station IDs, meaning that any station ID that is missing (is null) should be excluded.
#
# **Note2:** the question doesn't specify `start_station_id` or `end_station_id` and refers to all the station IDs. You would need to use a UNION to merge them all.
#
# **Note3:** `start_station_id` is listed as INT but `end_station_id` is STR. To do a UNION, you must have all of the columns in the same format and the same data type. Convert `start_station_id` to STR: I.e, `CAST(start_station_id AS STRING)`
#
# **Hint:** some records have `end_station_id` as `'Event'`. Since these do not qualify as valid station IDs we will have to exclude them.

# %%
# %%bigquery  --project=ba-770
# # Your answer goes here
# SELECT COUNT(*) AS count_unique_stations FROM (
# SELECT DISTINCT CAST(start_station_id AS STRING) AS station_id FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# UNION DISTINCT
# SELECT DISTINCT end_station_id AS station_id FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`)
# WHERE station_id IS NOT NULL AND station_id!='Event'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    count_unique_stations
# 0                    106

# %% [markdown]
# ### Question 7&8
# Which station has the highest number of trips that start from and end at that station?

# %%
# %%bigquery  --project=ba-770
# # Your answer goes here
# SELECT start_station_id, end_station_id, count(*) trips FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# WHERE CAST(start_station_id AS STRING) = end_station_id
# GROUP BY start_station_id, end_station_id
# ORDER BY trips DESC
# LIMIT 1
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    start_station_id end_station_id  trips
# 0              3798           3798  19850

# %% [markdown]
# ### Question 9&10
# Which station is the most popular destination?

# %%
# %%bigquery  --project=ba-770
# # Your answer goes here
# SELECT end_station_id, count(*) trips FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# GROUP BY end_station_id
# ORDER BY trips DESC
# LIMIT 1
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   end_station_id   trips
# 0           3798  179551

# %% [markdown]
# ### Question 11&12
# How many different types of subscribers appear in this dataset?

# %%
# %%bigquery  --project=ba-770
# SELECT COUNT(DISTINCT subscriber_type) FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0   60

# %% [markdown]
# ### Question 13&14
# Which one is by far the most popular subscriber plan?

# %%
# %%bigquery  --project=ba-770
# # Your answer goes here
# SELECT subscriber_type, count(*) subs FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# GROUP BY subscriber_type
# ORDER BY subs DESC
# LIMIT 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#            subscriber_type    subs
# 0       Student Membership  430347
# 1                 Local365  389728
# 2  U.T. Student Membership  289108
# 3     24 Hour Walk Up Pass  272860
# 4                  Walk Up  260044

# %% [markdown]
# ### Question 15&16
# How many bike rides are in this dataset?

# %%
# %%bigquery  --project=ba-770
# # Your answer goes here
# SELECT COUNT(*) FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        f0_
# 0  2271152

# %% [markdown]
# ### Question 17&18
# Which month was the busiest month in 2024?
#
# Hint: Use the EXTRACT function to extract the date components. For more help, go to the documentation: https://cloud.google.com/bigquery/docs/reference/standard-sql/date_functions

# %%
# %%bigquery  --project=ba-770
# # Your answer goes here
# SELECT EXTRACT(MONTH FROM start_time) month, count(*) rides FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# WHERE EXTRACT(YEAR FROM start_time) = 2024
# GROUP BY month
# ORDER BY rides DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    month  rides
# 0      4  33203
# 1      3  32207
# 2      2  28102
# 3      5  17764
# 4      1  15490
# 5      6  14378
